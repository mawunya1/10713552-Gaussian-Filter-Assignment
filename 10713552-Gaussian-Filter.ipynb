# %%
import numpy as np
import math
def gaussianFilter(image,size_of_kernel):
    kernel =  np.fromfunction(lambda x, y: (1/(2*math.pi*1**2)) * math.e ** ((-1*((x-(size_of_kernel-1)/2)**2+(y-(size_of_kernel-1)/2)**2))/(2*1**2)), (size_of_kernel, size_of_kernel))
    print(kernel / np.sum(kernel))
    kernel = generate_kernel(kernel_size)
    kern = int((kernel_size-1)/2)
    gaussian = np.zeros((img.shape[0]-2*kern, img.shape[1]-2*kern))
    for y in range(kern, img.shape[0]-kern):
        for x in range(kern, img.shape[1]-kern):
            gaussian[y-kern][x-kern] = np.sum(np.multiply(img[y-kern:y+kern+1, x-kern:x+kern+1], kernel))
    print("Filtered Image below")
    return gaussian
image= np.random.rand(10, 10)
print(image)
gaussianFilter(image,3)
# Out:
# [[0.43751152 0.20132407 0.75639609 0.32291976 0.5529383  0.93643965
#   0.37372124 0.94898043 0.30188458 0.34530402]
#  [0.9158355  0.90856539 0.98269737 0.85010419 0.18566896 0.02405787
#   0.91376426 0.31903389 0.75812661 0.41639116]
#  [0.10895432 0.57878178 0.0853559  0.69126345 0.76746176 0.59143597
#   0.14540086 0.14076375 0.06539752 0.83674446]
#  [0.10529131 0.98191668 0.30423289 0.86418198 0.53530212 0.4452347
#   0.8477387  0.53519867 0.3579666  0.40556849]
#  [0.87950506 0.72033111 0.81272306 0.51130012 0.30078218 0.55549997
#   0.96815536 0.03603339 0.65476841 0.11458026]
#  [0.30066397 0.45516798 0.96855211 0.17332273 0.64475031 0.34901347
#   0.12076847 0.9981898  0.03780987 0.85078884]
#  [0.0355571  0.727556   0.51760433 0.44389211 0.39625772 0.23614498
#   0.24417426 0.85930461 0.16727622 0.78722551]
#  [0.19756955 0.43467746 0.05149244 0.49879002 0.58500043 0.16714158
#   0.89122134 0.55618913 0.32855298 0.33819053]
# ...
